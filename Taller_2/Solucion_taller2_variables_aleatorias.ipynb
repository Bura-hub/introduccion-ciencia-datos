# %% [markdown]
# <a href="https://colab.research.google.com/github/elessardari/IDC-MaIE_2026A/blob/main/icd_taller2_variables_aleatorias.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **¡¡ ANTES DE EMPEZAR !!**
#
# Deshabilita autocompletar con IA. Esta acción te ayudará a aprender de verdad. Si estás en Colab sigue estos pasos:
#
#
#
# 1.   Ir a Herramientas \ Configuración \ Asistencia de IA
# 2.   Desactivar la casilla **"Mostrar autocompletado impulsado por IA"**
# 3.   Activar la casilla **"Ocultar funciones de IA generativa"**

# %% [markdown]
# # **SIMULACIÓN DE VARIABLES ALEATORIAS DISCRETAS**
#
# En este taller utilizaremos la librería `numpy` para la generación de números aleatorios y la simulación de experimentos con incertidumbre. Adicionalmente, emplearemos la librería `matplotlib.pyplot` para la visualización gráfica de las **distribuciones de probabilidad** mediante diagramas de barras e histogramas.
#
# El objetivo de este taller es aplicar los conceptos teóricos de variables aleatorias discretas y sus funciones de masa, simulando experimentos repetidos para observar su comportamiento a largo plazo (técnica conocida como **simulación de Montecarlo**).

# %%
# Importamos las librerías necesarias para el desarrollo del taller.
# 'numpy' se utiliza para arreglos numéricos y generación de valores aleatorios.
# 'matplotlib.pyplot' para la creación de gráficos
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1. Construcción a Partir de Datos de una Función de Masa: Suma de 2 Dados
#
# A continuación, simularemos el lanzamiento de dos dados. Posteriormente, construiremos la función de masa de probabilidad para la variable aleatoria definida como el resultado de cada lanzamiento.

# %%
# -- Versión 1 --
# Definimos el número total de experimentos o simulaciones a realizar (tamaño de la muestra)
N = 10000

# La función np.random.randint(low, high) genera un números enteros aleatorio.
# El límite inferior ('low') es inclusivo, mientras que el límite superior ('high') es exclusivo.
# Todos los números tienen la misma probabilidad de ocurrir.
# Por lo tanto, para simular un dado de 6 caras, los límites son 1 y 7.

# Para ver 'randint' en funcionamiento, simulemos el lanzamiento de 1 dado:
# Nota: cada vez que se ejecute el código, el resultado de 'randint' cambiará
dado1 = np.random.randint(1,7)
print(f'El dado cayó en {dado1}')

# Simulamos el lanzamiento de los 2 dados N veces
resultados = []
for prueba in range(N):
  dado1 = np.random.randint(1,7)
  dado2 = np.random.randint(1,7)
  suma = dado1 + dado2
  resultados.append(suma)

# La función np.unique() identifica los valores únicos presentes en un arreglo.
# Al establecer 'return_counts=True', la función también devuelve la frecuencia absoluta de cada valor.
valores, conteos = np.unique(resultados, return_counts=True)

# Calculamos la frecuencia relativa (probabilidad empírica) dividiendo los conteos entre el total de experimentos.
probabilidades_empiricas = conteos / N

# Inicializamos la figura para el gráfico y definimos sus dimensiones (ancho, alto) en pulgadas.
plt.figure(figsize=(8, 5))

# plt.bar(x, height) genera un diagrama de barras.
# 'x' representa las categorías (valores posibles) y 'height' representa las alturas (probabilidades).
# El parámetro 'edgecolor' añade un contorno a las barras para mejorar la visualización.
plt.bar(valores, probabilidades_empiricas, color='#3b82f6', edgecolor='black')

# Asignamos el título principal y las etiquetas correspondientes a los ejes coordenados.
plt.title('Función de masa empírica: Suma de dos dados')
plt.xlabel('Resultado (x)')
plt.ylabel('Probabilidad p(x)')

# plt.xticks() fuerza explícitamente las marcas en el eje x para asegurar que se muestren todos los números del 2 al 12.
plt.xticks(range(2, 13))

# plt.show() muestra la figura
plt.show()
# Out:
# El dado cayó en 4

# %%
# -- Versión 2: Optimizada (cambiando el 'for' por operaciones vectoriales) --

N = 10000 # Número de experimentos

# Vamos a usar el parámetro 'size' en la función np.random.randint(low, high, size),
# Ahora, la función genera un arreglo de números enteros aleatorios de tamaño 'size'
dado1 = np.random.randint(1, 7, N)
dado2 = np.random.randint(1, 7, N)

# Realizamos la suma de los arreglos elemento a elemento para obtener la variable aleatoria de interés.
suma_dados = dado1 + dado2

# Realizamos el conteo:
valores, conteos = np.unique(suma_dados, return_counts=True)

# Calculamos la frecuencia relativa:
probabilidades_calculadas = conteos / N

# Graficamos:
plt.figure(figsize=(8, 5))

# plt.bar(x, height) genera un diagrama de barras.
# 'x' representa las categorías (valores posibles) y 'height' representa las alturas (probabilidades).
# El parámetro 'edgecolor' añade un contorno a las barras para mejorar la visualización.
plt.bar(valores, probabilidades_calculadas, color='#3b82f6', edgecolor='black')

# Asignamos el título principal y las etiquetas correspondientes a los ejes coordenados.
plt.title('Función de masa empírica: Suma de dos dados')
plt.xlabel('Suma obtenida (x)')
plt.ylabel('Probabilidad p(x)')

# plt.xticks() fuerza explícitamente las marcas en el eje x para asegurar que se muestren todos los números del 2 al 12.
plt.xticks(range(2, 13))

# plt.show() renderiza y despliega la figura generada en la salida de la celda.
plt.show()

# %% [markdown]
# **¿Qué sucede si el número de experimentos simulados se reduce mucho?**

# %% [markdown]
# ## 2. Distribución Binomial: Simulación vs. Teoría
#
# La distribución binomial modela la probabilidad de obtener exactamente $x$ "éxitos" en una secuencia de $n$ pruebas independientes, donde cada prueba tiene una probabilidad de éxito constante $a$.
#
# En esta sección, no solo simularemos un proceso binomial, sino que superpondremos la **función de masa teórica** (calculada matemáticamente) sobre nuestra **función de masa empírica** (obtenida por simulación) para analizar qué tanto se aproximan.
#
# **Contexto práctico:** Una campaña de marketing digital envía correos promocionales en lotes de 20 mensajes ($n = 20$). Históricamente, la probabilidad de que un usuario haga clic en el enlace es del 30%. Deseamos analizar la distribución del número de clics obtenidos por lote.

# %%
# Importamos math para calcular el 'número combinatorio', que usaremos para el cálculo teórico de la distribución binomial

# Importamos el módulo 'stats' de SciPy, para probabilidad y estadística en Python.
# Específicamente, importamos 'bernoulli'. Esta función retorna el resultado de un experimento de Bernoulli.
# Un experimento de Bernoulli es una prueba aleatoria con dos resultados posibles:
#"1" ("éxito") con probabilidad a y "0" ("fracaso") con probabilidad (1-a).
# Esto es justo lo que necesitamos para simular una variable aleatoria binomial

import math
from scipy.stats import bernoulli

# Para ver 'bernoulli' en funcionamiento, simulemos el resultado de 1 experimento de Bernoulli.
# Nota: cada vez que se ejecute el código, el resultado de 'randint' cambiará

# bernoulli.rvs(a) ejecuta la prueba de Bernoulli con probabilidad de éxito a
resultado_experimento = bernoulli.rvs(0.5)
print(f'El resultado del experimento de Bernoulli es {resultado_experimento}')

# ==========================================
# 0. EXPERIMENTO BINOMIAL
# ==========================================

# Definimos los parámetros del experimento binomial
n = 20        # Número de correos enviados por lote (n)
a = 0.30     # Probabilidad teórica de clic (a)
N = 1000 # Cantidad de lotes a simular (tamaño de la muestra)

# ==========================================
# 1. CÁLCULO EMPÍRICO (Simulación de Montecarlo)
# ==========================================

clics_simulados = [] # Esta lista almacenará el número de clics por lote
for lote in range(N):
  clics_lote = 0 # Esta variable contará el número de clics en un lote
  for correo in range(n):
    exito = bernoulli.rvs(a) # Simulamos si el usuario hizo o no clic
    clics_lote = clics_lote + exito
  clics_simulados.append(clics_lote)

# Calculamos las frecuencias relativas (probabilidad empírica)
valores_emp, conteos_emp = np.unique(clics_simulados, return_counts=True)
prob_empirica = conteos_emp / N

# ==========================================
# 2. CÁLCULO TEÓRICO
# ==========================================
# np.arange(start, stop) crea un arreglo con todos los valores posibles de x (de 0 a 20 clics).
x_teorico = np.arange(0, n+1)

prob_teorica = [] # Lista donde almacenaremos las probabilidades teóricas de cada valor de x
for x in x_teorico:
  # Evaluamos la fórmula de la función de masa binomial para cada valor de x (clics)
  prob_x = math.comb(n,x)*(a**x)*(1-a)**(n-x) # math.comb(n,x) calcula el número combinatorio de n sobre x
  prob_teorica.append(prob_x)

# ==========================================
# 3. VISUALIZACIÓN COMPARATIVA
# ==========================================
plt.figure(figsize=(10, 6))

# Graficamos la distribución empírica usando un diagrama de barras (azul claro)
plt.bar(valores_emp, prob_empirica, color='#93c5fd', edgecolor='black', label='Empírica (Simulación)')

# Superponemos la distribución teórica usando una línea con marcadores (rojo)
plt.plot(x_teorico, prob_teorica, 'ro-', linewidth=2, markersize=6, label='Teórica (Fórmula)')

# Configuraciones estéticas del gráfico
plt.title(f'Distribución Binomial ($n={n}, a={a}$): Empírica vs Teórica')
plt.xlabel('Número de clics por lote (x)')
plt.ylabel('Probabilidad p(x)')
plt.xticks(range(0, n+1))
plt.legend() # Muestra el cuadro explicativo con las etiquetas (labels)
plt.grid(axis='y', linestyle='--', alpha=0.5)

plt.show()
# Out:
# El resultado del experimento de Bernoulli es 1

# %% [markdown]
# ---
# # Reto 1: Toma de Decisiones Gerenciales bajo Incertidumbre
#
# **Contexto del Negocio:**
# Usted es el gerente de análisis de datos de la empresa. Tras revisar los resultados del envío de correos (donde $n=20$ y $a=0.30$), la junta directiva le ha pedido una recomendación para aumentar las ganancias de la campaña promocional.
#
# El departamento de finanzas ha establecido los siguientes parámetros:
# * Cada cliente que hace clic en el correo (un "éxito") genera un retorno neto promedio de **$100 USD**.
#
# El equipo de marketing propone dos estrategias alternativas:
#
# * **Estrategia A (Invertir en Calidad):** Contratar a una agencia de diseño para mejorar el contenido del correo. El tamaño del lote se mantiene en $n = 20$ correos, pero el diseño persuasivo aumenta la probabilidad de éxito a $a = 0.60$. El costo total de diseño y envío para este lote "premium" es de **$300 USD**.
#
# * **Estrategia B (Invertir en Volumen):** Mantener el diseño actual con $a = 0.30$, pero adquirir una infraestructura de software masiva que permite enviar lotes más grandes de $n = 50$ correos. El costo operativo de enviar este lote masivo es de **$400 USD**.
#
# **Entregables (mediante Simulaciones de Montecarlo):**
# 1. Encontrar la **distribución de probabilidad** de clics para cada estrategia.
# 2. Calcular el **valor esperado** y la **desviación estándar** (raíz cuadrada de la varianza) de clics  para cada estrategia.
# 3. Encontrar la distribución de probabilidad de la **ganancia** para cada escenario (**ganancia** = **ingresos** - **costos**).
# 4. Calcular la **ganancia esperada** y su **desviación estándar**.
# 5. Dar una recomendación sustentada a la gerencia.

# %%
# --- CÓDIGO PROBLEMA TOMA DE DECISIONES GERENCIALES ---
import math
from scipy.stats import bernoulli

# Parámetros del problema
# El límite inferior ('low') es inclusivo, mientras que el límite superior ('high') es exclusivo.
# Todos los números tienen la misma probabilidad de ocurrir.
# Por lo tanto, para simular un dado de 6 caras, los límites son 1 y 7.

# Parámetros del problema
ingreso_por_clic = 100
N_sim = 10000

n_A, a_A, costo_A = 20, 0.60, 300
# Estrategia B: n=50, a=0.30, costo=$400
n_B, a_B, costo_B = 50, 0.30, 400

# Simulación Montecarlo para ambas estrategias
clics_A = []
clics_B = []
for i in range(N_sim):
    clics_A.append(sum(bernoulli.rvs(a_A, size=n_A)))
    clics_B.append(sum(bernoulli.rvs(a_B, size=n_B)))

print(clics_A)
print(clics_B)

# 1. Distribución de probabilidad de clics
val_A, count_A = np.unique(clics_A, return_counts=True)
val_B, count_B = np.unique(clics_B, return_counts=True)
prob_A = count_A / N_sim
prob_B = count_B / N_sim

# 2. Valor esperado y desviación estándar de clics
E_clics_A, std_clics_A = np.mean(clics_A), np.std(clics_A)
E_clics_B, std_clics_B = np.mean(clics_B), np.std(clics_B)

print("=== CLICS ===")
print(f"Estrategia A: E[clics]={E_clics_A:.2f}, σ(clics)={std_clics_A:.2f}")
print(f"Estrategia B: E[clics]={E_clics_B:.2f}, σ(clics)={std_clics_B:.2f}")

# 3. Distribución de ganancia (ingresos - costos)
ganancia_A = np.array(clics_A) * ingreso_por_clic - costo_A
ganancia_B = np.array(clics_B) * ingreso_por_clic - costo_B
print(ganancia_A)
print(ganancia_B)

val_gan_A, count_gan_A = np.unique(ganancia_A, return_counts=True)
val_gan_B, count_gan_B = np.unique(ganancia_B, return_counts=True)
prob_gan_A = count_gan_A / N_sim
prob_gan_B = count_gan_B / N_sim

# 4. Ganancia esperada y desviación estándar
E_gan_A, std_gan_A = np.mean(ganancia_A), np.std(ganancia_A)
E_gan_B, std_gan_B = np.mean(ganancia_B), np.std(ganancia_B)
print("\n=== GANANCIA (USD) ===")
print(f"Estrategia A: E[ganancia]=${E_gan_A:.2f}, σ(ganancia)=${std_gan_A:.2f}")
print(f"Estrategia B: E[ganancia]=${E_gan_B:.2f}, σ(ganancia)=${std_gan_B:.2f}")

# 5. Visualización comparativa
fig, axes = plt.subplots(2, 2, figsize=(12, 10))

# Distribución de clics
axes[0,0].bar(val_A, prob_A, color='#3b82f6', edgecolor='black', alpha=0.8, label='Empírica')
x_teo_A = np.arange(0, n_A+1)
prob_teo_A = [math.comb(n_A,k)*(a_A**k)*((1-a_A)**(n_A-k)) for k in x_teo_A]
axes[0,0].plot(x_teo_A, prob_teo_A, 'ro-', markersize=4, label='Teórica')
axes[0,0].set_title('Estrategia A: Distribución de clics (n=20, a=0.60)')
axes[0,0].set_xlabel('Clics')
axes[0,0].set_ylabel('Probabilidad')
axes[0,0].legend()
axes[0,0].grid(axis='y', alpha=0.3)

axes[0,1].bar(val_B, prob_B, color='#22c55e', edgecolor='black', alpha=0.8, label='Empírica')
x_teo_B = np.arange(0, n_B+1)
prob_teo_B = [math.comb(n_B,k)*(a_B**k)*((1-a_B)**(n_B-k)) for k in x_teo_B]
axes[0,1].plot(x_teo_B, prob_teo_B, 'ro-', markersize=4, label='Teórica')
axes[0,1].set_title('Estrategia B: Distribución de clics (n=50, a=0.30)')
axes[0,1].set_xlabel('Clics')
axes[0,1].set_ylabel('Probabilidad')
axes[0,1].legend()
axes[0,1].grid(axis='y', alpha=0.3)

# Distribución de ganancia
axes[1,0].bar(val_gan_A, prob_gan_A, color='#3b82f6', edgecolor='black', alpha=0.8)
axes[1,0].axvline(E_gan_A, color='red', linestyle='--', label=f'E[ganancia]=${E_gan_A:.0f}')
axes[1,0].set_title('Estrategia A: Distribución de ganancia')
axes[1,0].set_xlabel('Ganancia (USD)')
axes[1,0].set_ylabel('Probabilidad')
axes[1,0].legend()
axes[1,0].grid(axis='y', alpha=0.3)

axes[1,1].bar(val_gan_B, prob_gan_B, color='#22c55e', edgecolor='black', alpha=0.8)
axes[1,1].axvline(E_gan_B, color='red', linestyle='--', label=f'E[ganancia]=${E_gan_B:.0f}')
axes[1,1].set_title('Estrategia B: Distribución de ganancia')
axes[1,1].set_xlabel('Ganancia (USD)')
axes[1,1].set_ylabel('Probabilidad')
axes[1,1].legend()
axes[1,1].grid(axis='y', alpha=0.3)

plt.tight_layout()
plt.show()

# 5. Recomendación
print("\n=== RECOMENDACIÓN ===")
if E_gan_A > E_gan_B:
    print(f"Se recomienda la Estrategia A (Invertir en Calidad). Ganancia esperada mayor: ${E_gan_A:.2f} vs ${E_gan_B:.2f}")
else:
    print(f"Se recomienda la Estrategia B (Invertir en Volumen). Ganancia esperada mayor: ${E_gan_B:.2f} vs ${E_gan_A:.2f}")
# Out:
# [np.int64(12), np.int64(16), np.int64(17), np.int64(13), np.int64(12), np.int64(17), np.int64(12), np.int64(12), np.int64(9), np.int64(11), np.int64(9), np.int64(15), np.int64(14), np.int64(14), np.int64(12), np.int64(10), np.int64(17), np.int64(12), np.int64(11), np.int64(7), np.int64(13), np.int64(7), np.int64(10), np.int64(13), np.int64(9), np.int64(14), np.int64(14), np.int64(13), np.int64(14), np.int64(14), np.int64(12), np.int64(13), np.int64(12), np.int64(11), np.int64(13), np.int64(17), np.int64(10), np.int64(15), np.int64(13), np.int64(14), np.int64(11), np.int64(11), np.int64(12), np.int64(13), np.int64(12), np.int64(14), np.int64(9), np.int64(9), np.int64(13), np.int64(18), np.int64(13), np.int64(13), np.int64(15), np.int64(12), np.int64(14), np.int64(15), np.int64(9), np.int64(10), np.int64(12), np.int64(12), np.int64(13), np.int64(13), np.int64(11), np.int64(10), np.int64(12), np.int64(13), np.int64(13), np.int64(10), np.int64(14), np.int64(14), np.int64(10), np.int64(13), np.int64(14), np.int64(16), np.int64(12), np.int64(15), np.int64(8), np.int64(12), np.int64(13), np.int64(14), np.int64(8), np.int64(12), np.int64(12), np.int64(13), np.int64(14), np.int64(13), np.int64(14), np.int64(11), np.int64(10), np.int64(14), np.int64(12), np.int64(15), np.int64(12), np.int64(14), np.int64(10), np.int64(9), np.int64(12), np.int64(9), np.int64(12), np.int64(11), np.int64(13), np.int64(11), np.int64(10), np.int64(15), np.int64(8), np.int64(9), np.int64(15), np.int64(11), np.int64(9), np.int64(11), np.int64(12), np.int64(9), np.int64(12), np.int64(12), np.int64(14), np.int64(14), np.int64(13), np.int64(13), np.int64(14), np.int64(9), np.int64(12), np.int64(16), np.int64(14), np.int64(14), np.int64(9), np.int64(14), np.int64(11), np.int64(10), np.int64(9), np.int64(12), np.int64(11), np.int64(11), np.int64(13), np.int64(12), np.int64(13), np.int64(11), np.int64(12), np.int64(15), np.int64(10), np.int64(12), np.int64(10), np.int64(9), np.int64(11), np.int64(15), np.int64(10), np.int64(7), np.int64(11), np.int64(8), np.int64(15), np.int64(14), np.int64(11), np.int64(9), np.int64(14), np.int64(13), np.int64(10), np.int64(9), np.int64(13), np.int64(13), np.int64(9), np.int64(8), np.int64(8), np.int64(13), np.int64(7), np.int64(12), np.int64(12), np.int64(10), np.int64(13), np.int64(11), np.int64(11), np.int64(10), np.int64(7), np.int64(9), np.int64(15), np.int64(9), np.int64(9), np.int64(9), np.int64(9), np.int64(10), np.int64(12), np.int64(8), np.int64(9), np.int64(17), np.int64(10), np.int64(11), np.int64(11), np.int64(11), np.int64(13), np.int64(16), np.int64(11), np.int64(10), np.int64(15), np.int64(11), np.int64(15), np.int64(13), np.int64(7), np.int64(15), np.int64(15), np.int64(13), np.int64(15), np.int64(16), np.int64(11), np.int64(13), np.int64(9), np.int64(16), np.int64(16), np.int64(10), np.int64(10), np.int64(12), np.int64(11), np.int64(12), np.int64(15), np.int64(15), np.int64(7), np.int64(14), np.int64(13), np.int64(13), np.int64(15), np.int64(9), np.int64(14), np.int64(11), np.int64(11), np.int64(9), np.int64(8), np.int64(12), np.int64(14), np.int64(11), np.int64(14), np.int64(13), np.int64(11), np.int64(12), np.int64(10), np.int64(8), np.int64(8), np.int64(10), np.int64(12), np.int64(12), np.int64(10), np.int64(14), np.int64(9), np.int64(11), np.int64(9), np.int64(10), np.int64(9), np.int64(13), np.int64(13), np.int64(11), np.int64(11), np.int64(10), np.int64(13), np.int64(10), np.int64(13), np.int64(10), np.int64(12), np.int64(12), np.int64(13), np.int64(9), np.int64(9), np.int64(10), np.int64(12), np.int64(11), np.int64(12), np.int64(14), np.int64(13), np.int64(13), np.int64(10), np.int64(13), np.int64(14), np.int64(12), np.int64(11), np.int64(7), np.int64(14), np.int64(7), np.int64(12), np.int64(9), np.int64(15), np.int64(12), np.int64(11), np.int64(15), np.int64(14), np.int64(13), np.int64(14), np.int64(12), np.int64(13), np.int64(13), np.int64(13), np.int64(13), np.int64(13), np.int64(12), np.int64(12), np.in ...
# [np.int64(18), np.int64(20), np.int64(9), np.int64(18), np.int64(13), np.int64(16), np.int64(18), np.int64(16), np.int64(20), np.int64(18), np.int64(17), np.int64(18), np.int64(17), np.int64(13), np.int64(14), np.int64(15), np.int64(12), np.int64(12), np.int64(11), np.int64(16), np.int64(12), np.int64(12), np.int64(21), np.int64(11), np.int64(20), np.int64(18), np.int64(14), np.int64(10), np.int64(15), np.int64(16), np.int64(15), np.int64(14), np.int64(15), np.int64(11), np.int64(14), np.int64(12), np.int64(16), np.int64(13), np.int64(15), np.int64(17), np.int64(18), np.int64(10), np.int64(19), np.int64(13), np.int64(6), np.int64(10), np.int64(16), np.int64(15), np.int64(16), np.int64(13), np.int64(19), np.int64(16), np.int64(16), np.int64(20), np.int64(16), np.int64(16), np.int64(15), np.int64(13), np.int64(16), np.int64(14), np.int64(16), np.int64(9), np.int64(16), np.int64(19), np.int64(23), np.int64(18), np.int64(17), np.int64(18), np.int64(13), np.int64(19), np.int64(13), np.int64(12), np.int64(14), np.int64(12), np.int64(15), np.int64(15), np.int64(15), np.int64(8), np.int64(20), np.int64(12), np.int64(18), np.int64(11), np.int64(15), np.int64(18), np.int64(12), np.int64(16), np.int64(18), np.int64(12), np.int64(17), np.int64(10), np.int64(17), np.int64(19), np.int64(16), np.int64(19), np.int64(20), np.int64(19), np.int64(11), np.int64(20), np.int64(13), np.int64(10), np.int64(15), np.int64(22), np.int64(16), np.int64(15), np.int64(15), np.int64(13), np.int64(8), np.int64(23), np.int64(13), np.int64(24), np.int64(19), np.int64(9), np.int64(17), np.int64(9), np.int64(9), np.int64(16), np.int64(14), np.int64(10), np.int64(14), np.int64(20), np.int64(14), np.int64(18), np.int64(13), np.int64(11), np.int64(13), np.int64(13), np.int64(11), np.int64(19), np.int64(17), np.int64(17), np.int64(17), np.int64(18), np.int64(14), np.int64(11), np.int64(16), np.int64(21), np.int64(12), np.int64(17), np.int64(14), np.int64(13), np.int64(19), np.int64(18), np.int64(18), np.int64(14), np.int64(22), np.int64(20), np.int64(10), np.int64(20), np.int64(15), np.int64(11), np.int64(19), np.int64(12), np.int64(19), np.int64(19), np.int64(18), np.int64(13), np.int64(15), np.int64(14), np.int64(15), np.int64(13), np.int64(19), np.int64(14), np.int64(12), np.int64(18), np.int64(14), np.int64(13), np.int64(16), np.int64(14), np.int64(17), np.int64(19), np.int64(21), np.int64(19), np.int64(14), np.int64(18), np.int64(19), np.int64(15), np.int64(19), np.int64(20), np.int64(11), np.int64(14), np.int64(12), np.int64(13), np.int64(18), np.int64(15), np.int64(13), np.int64(12), np.int64(22), np.int64(20), np.int64(15), np.int64(11), np.int64(16), np.int64(16), np.int64(17), np.int64(15), np.int64(14), np.int64(14), np.int64(17), np.int64(13), np.int64(12), np.int64(10), np.int64(18), np.int64(12), np.int64(14), np.int64(14), np.int64(14), np.int64(13), np.int64(21), np.int64(17), np.int64(10), np.int64(12), np.int64(17), np.int64(15), np.int64(15), np.int64(19), np.int64(21), np.int64(14), np.int64(15), np.int64(16), np.int64(19), np.int64(17), np.int64(13), np.int64(16), np.int64(19), np.int64(12), np.int64(19), np.int64(15), np.int64(14), np.int64(10), np.int64(13), np.int64(15), np.int64(22), np.int64(12), np.int64(16), np.int64(13), np.int64(14), np.int64(14), np.int64(11), np.int64(15), np.int64(10), np.int64(14), np.int64(23), np.int64(10), np.int64(14), np.int64(12), np.int64(11), np.int64(20), np.int64(21), np.int64(15), np.int64(11), np.int64(19), np.int64(14), np.int64(12), np.int64(13), np.int64(16), np.int64(17), np.int64(16), np.int64(16), np.int64(22), np.int64(17), np.int64(15), np.int64(10), np.int64(15), np.int64(15), np.int64(13), np.int64(18), np.int64(18), np.int64(13), np.int64(13), np.int64(14), np.int64(19), np.int64(14), np.int64(17), np.int64(14), np.int64(17), np.int64(17), np.int64(20), np.int64(14), np.int64(17), np.int64(16), np.int64(12), np.int64(11), np.int64(16), np.int64(22), np.int64(14), np.int64(14), np.int64(12), np. ...
# === CLICS ===
# Estrategia A: E[clics]=12.01, σ(clics)=2.19
# Estrategia B: E[clics]=15.01, σ(clics)=3.29
# [ 900 1300 1400 ...  900  800 1100]
# [1400 1600  500 ...  800  700  400]
#
# === GANANCIA (USD) ===
# Estrategia A: E[ganancia]=$900.78, σ(ganancia)=$219.29
# Estrategia B: E[ganancia]=$1101.14, σ(ganancia)=$329.14
# === RECOMENDACIÓN ===
# Se recomienda la Estrategia B (Invertir en Volumen). Ganancia esperada mayor: $1101.14 vs $900.78

# %% [markdown]
# # Reto 2: Otras Distribuciones de Probabilidad Típicas
#
# Aparte de la distribución binomial, existen otras distribuciones de probabilidad típicas. Por ejemplo, la distribución geométrica modela el número de ensayos (de Bernoulli) necesarios para obtener el **primer ''éxito''**. A diferencia de la distribución binomial (donde el número de ensayos $n$ es fijo), en la geométrica, la variable aleatoria es el número de ensayos.
#
# **Contexto Práctico (Análisis de Riesgo en la Aviación):**
# El miedo a volar es común, pero el análisis de datos nos permite cuantificar el riesgo real. Supongamos que la probabilidad de que un vuelo comercial experimente un "incidente aéreo" (definido como turbulencia severa, fallas mecánicas que obligan a un aterrizaje de emergencia o problemas de presurización) es del $1\%$ (estamos siendo fatalistas, en realidad esta probabilidad es mucho más baja).
#
# La variable aleatoria $X$ representa el **número de vuelos que una persona debe tomar hasta experimentar su primer incidente aéreo**.
#
# **Entregables del Reto:**
# 1. Simule la experiencia de 10,000 viajeros frecuentes (es posible que necesite usar un ciclo `while` puesto que el viaje en el que ocurre el incidente se desconoce de antemano).
# 2. A partir de las simulaciones, calcule la distribución del número de vuelos que un pasajero debe realizar hasta que experimenta su primer incidente. Luego, compárela gráficamente con la función de masa teórica de la distribución geométrica (la cual debe consultar). **Nota 1:** Para las gráficas, es conveniente agrupar $x$ en intervalos (ej. de 0 a 9 vuelos, de 10 a 19 vuelos, etc.). Si no se hace esto, la gráfica tendrá muchísimas barras y será difícil de interpretar.
#
# **Nota 2:** la probabilidad de que ocurra un evento grave en un vuelo es de alrededor de 1 en 5 millones. Muchísimo más baja que el supuesto de nuestro problema didáctico. Si hiciéramos la simulación con este dato real, ¿cuál sería el principal inconveniente?

# %%
# --- CÓDIGO PROBLEMA DISTRIBUCIÓN GEOMÉTRICA ---
from scipy.stats import geom

p_incidente = 0.01  # Probabilidad de incidente por vuelo
N_viajeros = 10000

# Simulación: para cada viajero, contar vuelos hasta el primer incidente
vuelos_hasta_incidente = []
for _ in range(N_viajeros):
    vuelos = 0
    while True:
        vuelos += 1
        if bernoulli.rvs(p_incidente) == 1:
            break
    vuelos_hasta_incidente.append(vuelos)

# Agrupar en intervalos: [1-10], [11-20], [21-30], ..., [91-100], [100+]
ancho_intervalo = 10
max_vuelos = max(vuelos_hasta_incidente)
bins = list(range(1, 102, ancho_intervalo)) + [max(101, max_vuelos + 1)]

# Histograma empírico
conteos_emp, bordes = np.histogram(vuelos_hasta_incidente, bins=bins)
prob_empirica = conteos_emp / N_viajeros
centros = [(bordes[i] + bordes[i+1]) / 2 for i in range(len(bordes)-1)]
# Para el último bin si es 100+: centro aproximado
if len(centros) > 0 and bordes[-1] > 100:
    centros[-1] = 105  # etiqueta representativa

# Probabilidad teórica geométrica para cada intervalo
# geom.pmf(k, p) = (1-p)^(k-1) * p para k=1,2,3,...
prob_teorica = []
etiquetas = []
for i in range(len(bordes)-1):
    low, high = int(bordes[i]), int(bordes[i+1])
    if high > 500:  # bin 100+
        prob_teo = 1 - geom.cdf(100, p_incidente)
    else:
        prob_teo = geom.cdf(high, p_incidente) - geom.cdf(low-1 if low>1 else 0, p_incidente)
    prob_teorica.append(prob_teo)
    etiquetas.append(f'{low}-{min(high,100)}' if high < 500 else '100+')

# Gráfico comparativo
x = np.arange(len(etiquetas))
ancho = 0.35
plt.figure(figsize=(12, 5))
plt.bar(x - ancho/2, prob_empirica, ancho, label='Empírica (Simulación)', color='#3b82f6', edgecolor='black')
plt.bar(x + ancho/2, prob_teorica, ancho, label='Teórica (Geométrica)', color='#ef4444', alpha=0.7, edgecolor='black')
plt.xlabel('Número de vuelos hasta primer incidente (agrupado)')
plt.ylabel('Probabilidad')
plt.title(f'Distribución Geométrica: vuelos hasta primer incidente (p={p_incidente})')
plt.xticks(x, etiquetas)
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# PREGUNTA: Si un pasajero ha viajado 100 veces sin problema, ¿cuál es la probabilidad de que su siguiente vuelo sufra un incidente?
# Estimación empírica: P(incidente en vuelo 101 | sobrevivió 100) = casos con incidente en 101 / casos que pasaron 100
vuelos_arr = np.array(vuelos_hasta_incidente)
n_pasaron_100 = (vuelos_arr > 100).sum()
n_incidente_101 = (vuelos_arr == 101).sum()
prob_emp_siguiente = n_incidente_101 / n_pasaron_100 if n_pasaron_100 > 0 else p_incidente
print(f"Entre los {n_pasaron_100} viajeros que sobrevivieron 100 vuelos, {n_incidente_101} tuvieron incidente en el vuelo 101.")
print(f"Probabilidad empírica (siguiente vuelo con incidente): {prob_emp_siguiente:.4f} ({prob_emp_siguiente*100:.2f}%)")
print(f"Teórica (propiedad de memoria): p = {p_incidente} ({p_incidente*100:.0f}%)")
print(f"\nRESPUESTA: La probabilidad de que el siguiente vuelo tenga incidente es ≈{prob_emp_siguiente:.2%} (empírica), coherente con p=1%.")
print("El historial pasado no afecta: cada vuelo es independiente (propiedad de pérdida de memoria).")
# Out:
# Entre los 3687 viajeros que sobrevivieron 100 vuelos, 40 tuvieron incidente en el vuelo 101.
# Probabilidad empírica (siguiente vuelo con incidente): 0.0108 (1.08%)
# Teórica (propiedad de memoria): p = 0.01 (1%)
#
# RESPUESTA: La probabilidad de que el siguiente vuelo tenga incidente es ≈1.08% (empírica), coherente con p=1%.
# El historial pasado no afecta: cada vuelo es independiente (propiedad de pérdida de memoria).

# %% [markdown]
# # Reto 3: Verificación Empírica de Distribuciones (Ingeniería IoT)
#
# En la práctica de la Ciencia de Datos, rara vez conocemos la distribución matemática exacta de un fenómeno por adelantado. Por lo general, recibimos un conjunto de datos en bruto y debemos "verificar" si se ajustan a un modelo teórico conocido.
#
# **Contexto del Problema (Sistema Heredado):**
# Una empresa agroindustrial cuenta con una red de sensores inalámbricos desplegada en un cultivo. El sistema es un proyecto heredado (legacy) del cual **se ha perdido toda la documentación técnica**. La empresa no sabe cuántos sensores hay instalados en total en el campo, ni conoce la probabilidad de falla de los equipos.
#
# El único dato disponible es un archivo de registro (log) extraído del servidor central (`df_registro_fallas`), el cual contiene el número de sensores que fallaron y no se conectaron durante cada día, registrado a lo largo de 1.000 días continuos.
#
# El ingeniero principal sospecha que los datos deberían seguir una **Distribución Binomial**.
#
# **Entregable:**
# Usted debe comprobar si la hipótesis del ingeniero principal es correcta o no. Para ello, deberá importar los datos, analizarlos y escribir el código necesario para sustentar su conclusión de manera visual. Además, a partir de estos datos debe intentar decifrar cuántos sensores hay instalados y su probabilidad de falla.

# %%
# --- CARGAR DATOS IOT ---

import pandas as pd

# 1. DEFINICIÓN DE LA FUENTE DE DATOS
# ID del archivo donde están las notas:
sheet_id = "1nL1bqEqmuixmvIyZ4i6vK3JwNLk-wnGHKeqbH6RZ2J0"
# Construimos la URL de exportación del archivo (el archivo está disponible en Google Drive):
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/export?format=csv"

# 2. CARGA DEL DataFrame
# Construimos nuestro DataFrame, llamado "df_iot", leyendo el archivo desde la URL:
df_registro_fallas = pd.read_csv(url)

# Veamos cómo es el DataFrame que acabamos de descargar:
display(df_registro_fallas)
# Out:
#      dia_operacion  fallas_conexion
# 0                1                7
# 1                2               12
# 2                3                9
# 3                4                8
# 4                5                5
# ..             ...              ...
# 995            996                4
# 996            997               11
# 997            998                5
# 998            999               12
# 999           1000                7
#
# [1000 rows x 2 columns]

# %%
# --- CÓDIGO PROBLEMA IOT ---
import math

# Distribución empírica de fallas por día
fallas = df_registro_fallas['fallas_conexion'].values
valores_emp, conteos_emp = np.unique(fallas, return_counts=True)
prob_empirica = conteos_emp / len(fallas)

# Estimación de n y p asumiendo distribución binomial
# E[X] = n*p, Var[X] = n*p*(1-p) => p = 1 - Var/E, n = E/p
media = np.mean(fallas)
varianza = np.var(fallas)
p_est = 1 - varianza / media if media > 0 else 0
n_est = int(round(media / p_est)) if p_est > 0 else 0

print(f"Estimación desde datos: n ≈ {n_est} sensores, p ≈ {p_est:.4f} (probabilidad de falla)")
print(f"Media empírica = {media:.2f}, Varianza empírica = {varianza:.2f}")

# Función de masa teórica binomial con parámetros estimados
x_teorico = np.arange(0, n_est + 1)
prob_teorica = np.array([math.comb(n_est, k) * (p_est**k) * ((1-p_est)**(n_est-k)) for k in x_teorico])

# Visualización: comparar empírica vs teórica
plt.figure(figsize=(10, 5))
plt.bar(valores_emp - 0.2, prob_empirica, width=0.4, label='Empírica (datos)', color='#3b82f6', edgecolor='black')
plt.bar(x_teorico + 0.2, prob_teorica, width=0.4, label='Teórica Binomial (n estimado, p estimado)', color='#ef4444', alpha=0.7, edgecolor='black')
plt.xlabel('Número de sensores que fallaron por día')
plt.ylabel('Probabilidad')
plt.title(f'Verificación: ¿Los datos siguen una Binomial? (n≈{n_est}, p≈{p_est:.3f})')
plt.legend()
plt.grid(axis='y', alpha=0.3)
plt.tight_layout()
plt.show()

# Conclusión
print("\n=== CONCLUSIÓN ===")
print("Si la distribución empírica se ajusta bien a la curva teórica binomial, la hipótesis del ingeniero es plausible.")
print(f"Se estima que hay aproximadamente {n_est} sensores instalados, con una probabilidad de falla diaria de {p_est:.2%} por sensor.")
# Out:
# Estimación desde datos: n ≈ 50 sensores, p ≈ 0.1499 (probabilidad de falla)
# Media empírica = 7.42, Varianza empírica = 6.31
# === CONCLUSIÓN ===
# Si la distribución empírica se ajusta bien a la curva teórica binomial, la hipótesis del ingeniero es plausible.
# Se estima que hay aproximadamente 50 sensores instalados, con una probabilidad de falla diaria de 14.99% por sensor.
